# %% [markdown]
# <a href="https://colab.research.google.com/github/rajkumar123sudo/rajkumar12345/blob/main/untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns


df = pd.read_csv(r"/netflix_titles.csv")
# print(df.head(5))
# df.describe()
# df.info()
# df.shape

# ye groupby karke type ke hisab se release_year ko de raha hai
df.groupby("type")["release_year"].describe()
print(df.groupby("type")["release_year"].describe())

# ye groupby karke type ke hisab se release_year ka description de raha hai
df['country'].value_counts()
print(df['country'].value_counts())

# isme se pata chalta hai ki har country me kitni movies release hui hai
df.groupby('country')['release_year'].describe()
print(df.groupby('country')['release_year'].describe())

# isse se pata chalta hai ki har country me kitni movies release hui hai aur unka release year kya hai
df.groupby('country')['release_year'].describe().sort_values(by='count', ascending=False)
print(df.groupby('country')['release_year'].describe().sort_values(by='count', ascending=False))

# ye filter karke top 10 countries ke release_year ko descending order me sort kar raha hai kitni jada movies release hui hai
df.filter(items=['country', 'release_year']).sort_values(by='release_year', ascending=False).head(5)
print(df.filter(items=['country', 'release_year']).sort_values(by='release_year', ascending=False).head(5))
# ye filter karke country aur release_year ko de raha hai aur release_year ke hisab se descending order me sort kar raha hai aur top 10 movies ko de raha hai
df[df['country'] == 'United States'].sort_values(by='release_year', ascending=False).head(5)
print(df[df['country'] == 'United States'].sort_values(by='release_year', ascending=False).head(5))

# ye filter karke United States ke movies ko release_year ke hisab se descending order me sort kar raha hai aur top 10 movies ko de raha hai
df[df['country'] == 'India'].sort_values(by='release_year', ascending=False).head(5)
print(df[df['country'] == 'India'].sort_values(by='release_year', ascending=False).head(5))




# this is a bar chart to show the distribution of movie and TV show in the dataset
plt.figure(figsize=(10, 6))
df['type'].value_counts().plot(kind='bar')
plt.title('Distribution of Movie and TV Show')
plt.xlabel('Type_movies and TV Shows')
plt.ylabel('Count_values')
plt.xticks(rotation=0)
plt.show()
plt.savefig("bar_charts.png")


# this is a line chart to show the distribution of release years in the dataset
plt.figure(figsize=(10, 6))
df['release_year'].value_counts().sort_index().plot(kind='line')
plt.title('Distribution of Release Years')
plt.xlabel("release_year")
plt.ylabel('count_values')
plt.xticks(rotation=45)
plt.show()
plt.savefig("line_chart.png")

# this is a pie chart to show the distribution of ratings in the dataset
# rating distribution
rating_counts = df['rating'].value_counts().head(10)
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(
    rating_counts,
    labels=rating_counts.index,
    autopct='%1.1f%%',
    # startangle=140,
    pctdistance=0.8,
    labeldistance=1.05,
    wedgeprops={'linewidth': 1, 'edgecolor': 'white'}
)
ax.axis('equal')
plt.title('Rating distribution')
plt.legend(
    title='Rating Categories',
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)
plt.tight_layout()
plt.savefig('pie_chart.png')
plt.show()

# this is a histogram to show the distribution of release years in the dataset
plt.figure(figsize=(10, 6))
sns.histplot(df['release_year'], bins=30, )
plt.title('Distribution of Release Years')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.show()
plt.savefig("histogram.png")


# heatmap to show the correlation between top 10 listed_in and release_year in the dataset
plt.figure(figsize=(12, 8))
plt.title('Correlation between listed_in and release_year')
heat_data = pd.crosstab(df['listed_in'].head(10), df['release_year'])
sns.heatmap(heat_data, cmap='coolwarm', linewidths=0.5)
plt.show()
plt.savefig("heatmap.png")
# heatmap to show listed_in in the dataset

# scatter plot to show the relationship between release_year and duration in the dataset
plt.figure(figsize=(10, 6))
# convert duration strings (minutes) to numeric, ignore "Seasons"
df['duration_num'] = np.nan
mask_min = df['duration'].str.contains('min', na=False)
df.loc[mask_min, 'duration_num'] = pd.to_numeric(df.loc[mask_min, 'duration'].str.extract(r'(\d+)')[0], errors='coerce')

sns.scatterplot(x='release_year', y='duration_num', data=df)
plt.title('Relationship between Release Year and Duration')
plt.xlabel('Release Year')
plt.ylabel('Duration')
plt.show()
plt.savefig("scatter_plot.png")
# Out:
#           count         mean       std     min     25%     50%     75%     max
# type
# Movie    6131.0  2013.121514  9.678169  1942.0  2012.0  2016.0  2018.0  2021.0
# TV Show  2676.0  2016.605755  5.740138  1925.0  2016.0  2018.0  2020.0  2021.0
# country
# United States                                                      2818
# India                                                               972
# United Kingdom                                                      419
# Japan                                                               245
# South Korea                                                         199
#                                                                    ...
# Mexico, United States, Spain, Colombia                                1
# Canada, Norway                                                        1
# Finland, Germany, Belgium                                             1
# Argentina, United States, Mexico                                      1
# United Kingdom, United States, Germany, Denmark, Belgium, Japan       1
# Name: count, Length: 748, dtype: int64
#                                                     count         mean  \
# country
# , France, Algeria                                     1.0  2014.000000
# , South Korea                                         1.0  2021.000000
# Argentina                                            56.0  2016.000000
# Argentina, Brazil, France, Poland, Germany, Den...    1.0  2017.000000
# Argentina, Chile                                      2.0  2011.500000
# ...                                                   ...          ...
# Venezuela                                             1.0  2017.000000
# Venezuela, Colombia                                   1.0  2007.000000
# Vietnam                                               7.0  2017.714286
# West Germany                                          1.0  1977.000000
# Zimbabwe                                              1.0  2017.000000
#
#                                                          std     min      25%  \
# country
# , France, Algeria                                        NaN  2014.0  2014.00
# , South Korea                                            NaN  2021.0  2021.00
# Argentina                                           7.336088  1985.0  2016.00
# Argentina, Brazil, France, Poland, Germany, Den...       NaN  2017.0  2017.00
# Argentina, Chile                                    7.778175  2006.0  2008.75
# ...                                                      ...     ...      ...
# Venezuela                                                NaN  2017.0  2017.00
# Venezuela, Colombia                                      NaN  2007.0  2007.00
# Vietnam                                             2.690371  2014.0  2015.50
# West Germany                                             NaN  1977.0  1977.00
# Zimbabwe                                                 NaN  2017.0  2017.00
#
#                                                        50%      75%     max
# country
# , France, Algeria                                   2014.0  2014.00  2014.0
# , South Korea                                       2021.0  2021.00  2021.0
# Argentina                                           2018.0  2019.25  2021.0
# Argentina, Brazil, France, Poland, Germany, Den...  2017.0  2017.00  2017.0
# Argentina, Chile                                    2011.5  2014.25  2017.0
# ...                                                    ...      ...     ...
# Venezuela                                           2017.0  2017.00  2017.0
# Venezuela, Colombia                                 2007.0  2007.00  2007.0
# Vietnam                                             2019.0  2019.50  2021.0
# West Germany                                        1977.0  1977.00  1977.0
# Zimbabwe                                            2017.0  2017.00  2017.0
#
# [748 rows x 8 columns]
#                       count         mean        std     min     25%     50%  \
# country
# United States        2818.0  2013.314762  10.370965  1942.0  2013.0  2017.0
# India                 972.0  2011.966049   9.663647  1959.0  2010.0  2015.0
# United Kingdom        419.0  2015.245823   6.570865  1974.0  2015.0  2017.0
# Japan                 245.0  2014.285714   6.526742  1979.0  2012.0  2017.0
# South Korea           199.0  2017.130653   2.894267  2004.0  2016.0  2017.0
# ...                     ...          ...        ...     ...     ...     ...
# Australia, Iraq         1.0  2015.000000        NaN  2015.0  2015.0  2015.0
# Venezuela               1.0  2017.000000        NaN  2017.0  2017.0  2017.0
# Venezuela, Colombia     1.0  2007.000000        NaN  2007.0  2007.0  2007.0
